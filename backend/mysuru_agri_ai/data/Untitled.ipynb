# %%
import os, pandas as pd

os.chdir(r"C:\Users\anaay\OneDrive\Desktop\weeeeee")  # project root
df = pd.read_csv(r"mysuru_agri_ai\data\data_season.csv")

print(df["yeilds"].describe())
print(df[["Area", "yeilds"]].head())
# Out:
# count      3158.000000
# mean      23258.976916
# std       58228.985033
# min           2.000000
# 25%         393.000000
# 50%        2783.000000
# 75%        6589.000000
# max      623687.000000
# Name: yeilds, dtype: float64
#     Area    yeilds
# 0   1279    2570.0
# 1  13283   27170.0
# 2  52119  114744.0
# 3    725    1402.0
# 4  12885   23456.0

# %%
df["yield_per_acre"] = df["yeilds"] / df["Area"].replace(0, pd.NA)
print(df["yield_per_acre"].describe())
# Out:
# count      3158.000000
# mean        608.221776
# std        5685.046735
# min           0.000039
# 25%           0.128130
# 50%           1.665300
# 75%          19.928526
# max      171739.000000
# Name: yield_per_acre, dtype: float64

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anaay\OneDrive\Desktop\weeeeee\mysuru_agri_ai\data\data_season.csv")
